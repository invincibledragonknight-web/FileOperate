# %% [markdown]
# # Deep Scholar File Reconstruction
#
# This notebook provides a lightweight entry point to the deterministic file reconstruction workflow.

# %%
from research_agent.prompts import FILE_RECONSTRUCTION_WORKFLOW_INSTRUCTIONS
print(FILE_RECONSTRUCTION_WORKFLOW_INSTRUCTIONS)

# %%
from research_agent.tools import list_uploads
print(list_uploads())
